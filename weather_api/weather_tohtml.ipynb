# %%
import pandas as pd

# %%
file = "weather.csv"

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#      Unnamed: 0                City Country  Latitude  Longitude  \
# 0             0             Peniche      PT     39.36      -9.38
# 1             1           Busselton      AU    -33.64     115.35
# 2             2               Alofi      NU    -19.06    -169.92
# 3             3        Karatuzskoye      RU     53.61      92.87
# 4             4            Thompson      CA     55.74     -97.86
# 5             5               Ambon      FR     47.55      -2.56
# 6             6          Brigantine      US     39.41     -74.36
# 7             7              Gashua      NG     12.87      11.04
# 8             8          Farmington      US     36.73    -108.21
# 9             9            Sisimiut      GL     66.94     -53.67
# 10           10           Carnarvon      ZA    -30.97      22.13
# 11           11             Ushuaia      AR    -54.81     -68.31
# 12           12        Punta Arenas      CL    -53.16     -70.91
# ...

# %%
del df["Unnamed: 0"]

# %%
df
# Out:
#                    City Country  Latitude  Longitude  Temperature(F)  \
# 0               Peniche      PT     39.36      -9.38           84.90
# 1             Busselton      AU    -33.64     115.35           55.84
# 2                 Alofi      NU    -19.06    -169.92           73.40
# 3          Karatuzskoye      RU     53.61      92.87           43.33
# 4              Thompson      CA     55.74     -97.86           39.20
# 5                 Ambon      FR     47.55      -2.56           71.60
# 6            Brigantine      US     39.41     -74.36           69.76
# 7                Gashua      NG     12.87      11.04           85.09
# 8            Farmington      US     36.73    -108.21           61.27
# 9              Sisimiut      GL     66.94     -53.67           38.11
# 10            Carnarvon      ZA    -30.97      22.13           62.23
# 11              Ushuaia      AR    -54.81     -68.31           50.81
# 12         Punta Arenas      CL    -53.16     -70.91           46.60
# ...

# %%
df.to_html("data.html")
